# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Hi'

# %%
os.chdir('C:\\Users\\Hi\\Desktop\\simplilearn\\datasets_python')

# %%
import pandas as pd

# %%
df1=pd.read_csv('car_price_prediction.csv')

# %%
df1
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df1[df1['Prod. year']>=2019]
# Out:
#              ID  Price  Levy   Manufacturer        Model  Prod. year Category  \
# 36     45369569  51746  1077         TOYOTA  CHR Limited        2019     Jeep
# 56     44316016  87112     -  MERCEDES-BENZ      GLA 250        2019     Jeep
# 81     45757322   7527   830         TOYOTA        Yaris        2019    Sedan
# 170    45765057    470  1077          MAZDA         1000        2019     Jeep
# 261    45804881  59865   879        HYUNDAI       Tucson        2019     Jeep
# ...         ...    ...   ...            ...          ...         ...      ...
# 19065  45524811   6586  1077         TOYOTA          CHR        2019     Jeep
# 19120  45771780   7213  1077         SUBARU    Crosstrek        2019    Sedan
# 19121  45732079  88438  1076        HYUNDAI     Santa FE        2020     Jeep
# 19157  45762367   3607  1077            KIA       Avella        2019    Sedan
# 19180  45803164  63886  1076        HYUNDAI       Sonata        2020    Sedan
#
# ...

# %%
df1.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
df1['Manufacturer'].unique()
# Out:
# array(['LEXUS', 'CHEVROLET', 'HONDA', 'FORD', 'HYUNDAI', 'TOYOTA',
#        'MERCEDES-BENZ', 'OPEL', 'PORSCHE', 'BMW', 'JEEP', 'VOLKSWAGEN',
#        'AUDI', 'RENAULT', 'NISSAN', 'SUBARU', 'DAEWOO', 'KIA',
#        'MITSUBISHI', 'SSANGYONG', 'MAZDA', 'GMC', 'FIAT', 'INFINITI',
#        'ALFA ROMEO', 'SUZUKI', 'ACURA', 'LINCOLN', 'VAZ', 'GAZ',
#        'CITROEN', 'LAND ROVER', 'MINI', 'DODGE', 'CHRYSLER', 'JAGUAR',
#        'ISUZU', 'SKODA', 'DAIHATSU', 'BUICK', 'TESLA', 'CADILLAC',
#        'PEUGEOT', 'BENTLEY', 'VOLVO', 'სხვა', 'HAVAL', 'HUMMER', 'SCION',
#        'UAZ', 'MERCURY', 'ZAZ', 'ROVER', 'SEAT', 'LANCIA', 'MOSKVICH',
#        'MASERATI', 'FERRARI', 'SAAB', 'LAMBORGHINI', 'ROLLS-ROYCE',
#        'PONTIAC', 'SATURN', 'ASTON MARTIN', 'GREATWALL'], dtype=object)

# %%
df1['Manufacturer'].value_counts()
# Out:
# HYUNDAI          3769
# TOYOTA           3662
# MERCEDES-BENZ    2076
# FORD             1111
# CHEVROLET        1069
#                  ...
# TESLA               1
# PONTIAC             1
# SATURN              1
# ASTON MARTIN        1
# GREATWALL           1
# Name: Manufacturer, Length: 65, dtype: int64

# %%
df1['Doors'].unique
# Out:
# <bound method Series.unique of 0        04-May
# 1        04-May
# 2        04-May
# 3        04-May
# 4        04-May
#           ...
# 19232    02-Mar
# 19233    04-May
# 19234    04-May
# 19235    04-May
# 19236    04-May
# Name: Doors, Length: 19237, dtype: object>

# %%
df1['Doors'].value_counts()
# Out:
# 04-May    18332
# 02-Mar      777
# >5          128
# Name: Doors, dtype: int64

# %%
df1[df1['Doors']=='>5']
# Out:
#              ID  Price  Levy Manufacturer    Model  Prod. year     Category  \
# 171    45782173   1300     -         AUDI       50        2018        Coupe
# 276    44810053  20385   738    CHEVROLET    Cruze        2017        Sedan
# 678    45800055   7213     -          BMW      525        1998        Sedan
# 829    45766759  30000     -       NISSAN  X-Trail        2018       Pickup
# 870    45788787  19757   810      HYUNDAI  Elantra        2016        Sedan
# ...         ...    ...   ...          ...      ...         ...          ...
# 18795  45788558  10976     -       TOYOTA     ISIS        2007      Minivan
# 18806  44839699  11917     -         FORD   Escape        2007         Jeep
# 19085  45794339  97219  1079        LEXUS   NX 300        2018         Jeep
# 19094  45804509  11290     -         FORD  Transit        2000  Goods wagon
# 19118  45738530  23834     -       TOYOTA  Alphard        2006      Minivan
#
# ...

# %%
df2=pd.read_csv('Car_sales.csv')

# %%
df2
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df2[df2['Price_in_thousands']>80]
# Out:
#    Manufacturer     Model  Sales_in_thousands  __year_resale_value  \
# 95   Mercedes-B  SL-Class               3.311                 58.6
# 99   Mercedes-B     CL500               0.954                  NaN
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 95    Passenger                82.6          5.0       302.0       99.0
# 99    Passenger                85.5          5.0       302.0      113.6
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 95   71.3   177.1        4.125           21.1             20.0     3/17/2011
# 99   73.1   196.6        4.115           23.2             20.0     4/11/2011
#
#     Power_perf_factor
# 95         139.982294
# 99         141.100985

# %%
import matplotlib.pyplot as plt
plt.scatter(df2['Price_in_thousands'], df2['Sales_in_thousands'],marker = '*')                 # 'r' is the color red
plt.xlabel('price of car in thousands ')                         # x axis label
plt.ylabel('Sales of car in thousands')             # y axis label
plt.title('sales w.r.t price')              # title of graph
plt.show()

# %%
df2[df2['Sales_in_thousands']>500]

# %%
df2.tail()

# %%
df3=pd.read_csv('newCarsIndia.csv')

# %%
df3
# Out:
#                         Car                 Style               Range  \
# 0             Tata Nexon EV           Compact SUV  312 Km/Full Charge
# 1    Hyundai Grand i10 Nios     Compact Hatchback    20.2 - 26.2 Km/l
# 2    Maruti Suzuki Alto 800       Entry Hatchback   24.7 - 31.39 Km/l
# 3                Tata Punch           Compact SUV                 NaN
# 4                 MG Hector                   SUV   13.96 - 17.4 Km/l
# ..                      ...                   ...                 ...
# 250        Porsche Panamera  Premium Sports Sedan              8 Km/l
# 251   Ferrari 812 Superfast  Premium Sports Coupe            6.7 Km/l
# 252      Ferrari California            Sports Car            9.5 Km/l
# 253       Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254                 MINI SE      Luxury Hatchback  270 Km/Full Charge
#
#          Transmission               VehicleType        PriceRange  \
# ...

# %%
df3['Style'].unique()
# Out:
# array(['Compact SUV', 'Compact Hatchback', 'Entry Hatchback', 'SUV',
#        'Subcompact SUV', 'Premium Hatchback', 'Compact MPV',
#        'Subcompact Sedan', 'Compact Sedan', 'Premium Fullsize SUV',
#        'Luxury SUV', 'Fullsize/Premium MPV', 'Supersports Car',
#        'Quadricycle', 'Subcompact MPV', 'Premium Midsize Sedan',
#        'Premium Luxury Sedan', 'Premium Compact Sedan',
#        'Compact SUV/Crossover', 'Midsize Sedan', 'Premium Coupe',
#        'Midsize SUV', 'Performance Sedan', 'Premium Midsize SUV',
#        'Premium Fullsize Sedan', 'Luxury Hatchback', 'Sports Car',
#        'Premium Sports Sedan', 'Premium Sports Coupe',
#        'Premium Compact SUV', 'Fullsize Sedan'], dtype=object)

# %%
df3['Range'].isna().value_counts()
# Out:
# False    244
# True      11
# Name: Range, dtype: int64

# %%
df3.isna().value_counts()
# Out:
# Car    Style  Range  Transmission  VehicleType  PriceRange  Rating(outof10)
# False  False  False  False         False        False       False              244
#               True   False         False        False       False               11
# dtype: int64

# %%
df3[df3['Rating(outof10)']=='na']
# Out:
#                        Car                 Style               Range  \
# 3               Tata Punch           Compact SUV                 NaN
# 11           Mahindra Thar           Compact SUV      13 - 15.2 Km/l
# 15         Mahindra XUV700                   SUV                 NaN
# 23         Hyundai Alcazar           Compact SUV    14.2 - 20.4 Km/l
# 26    Toyota Urban Cruiser        Subcompact SUV  17.03 - 18.76 Km/l
# ..                     ...                   ...                 ...
# 245      Audi RS E-Tron GT   Premium Midsize SUV  401 Km/Full Charge
# 248               BMW X3 M   Premium Midsize SUV           9.12 Km/l
# 251  Ferrari 812 Superfast  Premium Sports Coupe            6.7 Km/l
# 253      Ferrari Portofino  Premium Sports Coupe             10 Km/l
# 254                MINI SE      Luxury Hatchback  270 Km/Full Charge
#
#          Transmission    VehicleType         PriceRange Rating(outof10)
# ...
